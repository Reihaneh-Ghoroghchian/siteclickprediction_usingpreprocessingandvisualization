# %%
import numpy as np
import pandas as pd
import time 
from scipy.stats import norm
import matplotlib.pyplot as plt

# %% [markdown]
# In this computer assignment we get familiar with some of python's libraries including pandas.

# %% [markdown]
# part 1.

# %% [markdown]
# In this part we read the csv file which includes our dataset.
# This data is read as dataframe using pandas.

# %%
excel_file = 'advertising_dataset.csv'
ad_df = pd.read_csv(excel_file)

# %%
ad_df
# Out:
#      Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 0             0                     68.95  35.0     61833.90
# 1             1                     80.23  31.0     68441.85
# 2             2                     69.47  26.0     59785.94
# 3             3                     74.15  29.0     54806.18
# 4             4                     68.37  35.0     73889.99
# ..          ...                       ...   ...          ...
# 995         995                     72.97  30.0     71384.57
# 996         996                     51.30  45.0     67782.17
# 997         997                     51.63  51.0     42415.72
# 998         998                     55.55  19.0     41920.79
# 999         999                       NaN  26.0     29875.80
#
#      Daily Internet Usage                          Ad Topic Line  \
# 0                  256.09     Cloned 5thgeneration orchestration
# 1                     NaN     Monitored national standardization
# ...

# %% [markdown]
# Head fuction shows the n first rows of our dataset.
# If no number is provided, it shows the first 5 rows

# %%
#first rows def=5
ad_df.head(20)
# Out:
#     Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 0            0                     68.95  35.0     61833.90
# 1            1                     80.23  31.0     68441.85
# 2            2                     69.47  26.0     59785.94
# 3            3                     74.15  29.0     54806.18
# 4            4                     68.37  35.0     73889.99
# 5            5                     59.99  23.0     59761.56
# 6            6                     88.91  33.0     53852.85
# 7            7                     66.00  48.0     24593.33
# 8            8                     74.53  30.0     68862.00
# 9            9                     69.88  20.0     55642.32
# 10          10                     47.64  49.0     45632.51
# 11          11                     83.07  37.0     62491.01
# 12          12                       NaN  48.0     51636.92
# 13          13                     79.52   NaN     51739.63
# 14          14                     42.95  33.0     30976.00
# ...

# %% [markdown]
# tail shows the n last rows of our data set.
# If no number is provided is shows the last 5 rows

# %%
#last rows def=5
ad_df.tail(20)
# Out:
#      Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 980         980                     67.26  57.0     25682.65
# 981         981                     76.58  46.0     41884.64
# 982         982                     54.37  38.0     72196.29
# 983         983                     82.79  32.0     54429.17
# 984         984                     66.47  31.0     58037.66
# 985         985                     72.88  44.0     64011.26
# 986         986                       NaN  28.0     59967.19
# 987         987                     63.37  43.0     43155.19
# 988         988                     89.71  48.0     51501.38
# 989         989                     70.96  31.0     55187.85
# 990         990                     35.79  44.0     33813.08
# 991         991                     38.96  38.0     36497.22
# 992         992                     69.17  40.0     66193.81
# 993         993                     64.20  27.0     66200.96
# ...

# %% [markdown]
# Describe provides descriptive statistics including those that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.

# %%
ad_df.describe()
# Out:
#         Unnamed: 0  Daily Time Spent on Site         Age   Area Income  \
# count  1000.000000                907.000000  979.000000   1000.000000
# mean    499.500000                 64.794818   36.009193  55000.000080
# std     288.819436                 15.954841    8.783636  13414.634022
# min       0.000000                 32.600000   19.000000  13996.500000
# 25%     249.750000                 50.615000   29.000000  47031.802500
# 50%     499.500000                 67.940000   35.000000  57012.300000
# 75%     749.250000                 78.555000   42.000000  65470.635000
# max     999.000000                 91.430000   61.000000  79484.800000
#
#        Daily Internet Usage  Clicked on Ad
# count            913.000000     832.000000
# mean             179.751271       0.496394
# std               43.957934       0.500288
# min              104.780000       0.000000
# 25%              138.550000       0.000000
# 50%              183.480000       0.000000
# ...

# %% [markdown]
# part 2.

# %% [markdown]
#  Info fuction represents which variables are numerical and which are categorical

# %%
ad_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
# Unnamed: 0                  1000 non-null int64
# Daily Time Spent on Site    907 non-null float64
# Age                         979 non-null float64
# Area Income                 1000 non-null float64
# Daily Internet Usage        913 non-null float64
# Ad Topic Line               1000 non-null object
# City                        1000 non-null object
# Gender                      1000 non-null object
# Country                     1000 non-null object
# Timestamp                   1000 non-null object
# Clicked on Ad               832 non-null float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 86.1+ KB

# %% [markdown]
# Now using the replace fuction we replace "male" and "female" to 1 and 0 accordingly.

# %%
cleanup_nums = {"Gender":     {"Male": 1, "Female": 0}}
ad_df.replace(cleanup_nums, inplace=True)
ad_df.head()
# Out:
#    Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 0           0                     68.95  35.0     61833.90
# 1           1                     80.23  31.0     68441.85
# 2           2                     69.47  26.0     59785.94
# 3           3                     74.15  29.0     54806.18
# 4           4                     68.37  35.0     73889.99
#
#    Daily Internet Usage                          Ad Topic Line  \
# 0                256.09     Cloned 5thgeneration orchestration
# 1                   NaN     Monitored national standardization
# 2                236.50       Organic bottom-line service-desk
# 3                245.89  Triple-buffered reciprocal time-frame
# 4                225.58          Robust logistical utilization
#
#              City  Gender     Country            Timestamp  Clicked on Ad
# 0     Wrightburgh       0     Tunisia  2016-03-27 00:53:11            0.0
# 1       West Jodi       1       Nauru  2016-04-04 01:39:02            0.0
# ...

# %% [markdown]
# part 3.

# %% [markdown]
# We can use count fuction to find how many of the rows have numbers in each column

# %%
ad_df.count()
# Out:
# Unnamed: 0                  1000
# Daily Time Spent on Site     907
# Age                          979
# Area Income                 1000
# Daily Internet Usage         913
# Ad Topic Line               1000
# City                        1000
# Gender                      1000
# Country                     1000
# Timestamp                   1000
# Clicked on Ad                832
# dtype: int64

# %%
total_count = ad_df.count()[0]

# %% [markdown]
# Now we can calculate the empty rows by subtracting the number of not empty cells from the number of all the cells in each column

# %%
empty_rows = total_count - ad_df.count()
print(empty_rows)
# Out:
# Unnamed: 0                    0
# Daily Time Spent on Site     93
# Age                          21
# Area Income                   0
# Daily Internet Usage         87
# Ad Topic Line                 0
# City                          0
# Gender                        0
# Country                       0
# Timestamp                     0
# Clicked on Ad               168
# dtype: int64

# %% [markdown]
# In this part we drop the rows whose aim column is NaN

# %%
ad_df_without_NAN = ad_df[ad_df['Clicked on Ad'].notna()]
print(ad_df_without_NAN.head(15))
# Out:
# Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 0            0                     68.95  35.0     61833.90
# 1            1                     80.23  31.0     68441.85
# 2            2                     69.47  26.0     59785.94
# 3            3                     74.15  29.0     54806.18
# 4            4                     68.37  35.0     73889.99
# 5            5                     59.99  23.0     59761.56
# 6            6                     88.91  33.0     53852.85
# 7            7                     66.00  48.0     24593.33
# 8            8                     74.53  30.0     68862.00
# 9            9                     69.88  20.0     55642.32
# 11          11                     83.07  37.0     62491.01
# 12          12                       NaN  48.0     51636.92
# 13          13                     79.52   NaN     51739.63
# 16          16                     55.39  37.0     23936.86
# 17          17                     82.03  41.0     71511.08
#
# ...

# %%
ad_df_without_NAN.count() # it can be seen that the number of rows has decreased
# Out:
# Unnamed: 0                  832
# Daily Time Spent on Site    758
# Age                         815
# Area Income                 832
# Daily Internet Usage        758
# Ad Topic Line               832
# City                        832
# Gender                      832
# Country                     832
# Timestamp                   832
# Clicked on Ad               832
# dtype: int64

# %% [markdown]
# now we replace empty cells with average of their column

# %%
ad_df_without_NAN.mean()
# Out:
# Unnamed: 0                    496.939904
# Daily Time Spent on Site       65.065488
# Age                            35.977914
# Area Income                 54897.822284
# Daily Internet Usage          180.252968
# Gender                          0.491587
# Clicked on Ad                   0.496394
# dtype: float64

# %%
ad_df_without_NAN=ad_df_without_NAN.fillna(ad_df_without_NAN.mean())

# %%
ad_df_without_NAN.head(15)
# Out:
#     Unnamed: 0  Daily Time Spent on Site        Age  Area Income  \
# 0            0                 68.950000  35.000000     61833.90
# 1            1                 80.230000  31.000000     68441.85
# 2            2                 69.470000  26.000000     59785.94
# 3            3                 74.150000  29.000000     54806.18
# 4            4                 68.370000  35.000000     73889.99
# 5            5                 59.990000  23.000000     59761.56
# 6            6                 88.910000  33.000000     53852.85
# 7            7                 66.000000  48.000000     24593.33
# 8            8                 74.530000  30.000000     68862.00
# 9            9                 69.880000  20.000000     55642.32
# 11          11                 83.070000  37.000000     62491.01
# 12          12                 65.065488  48.000000     51636.92
# 13          13                 79.520000  35.977914     51739.63
# ...

# %% [markdown]
# we can see for example that daily internet usage in row number 11 has been replaced with mean

# %% [markdown]
# Another way is to repalce each empty cell with previous cell in the same column.
# The first way(replacing with mean) is better, because we won't have a problem if the first row has an empty cell, and also filling this empty cell won't change the overal mean of the column which is a very important characteristic of the dataset

# %% [markdown]
# part 4.

# %%
ad_df_without_NAN['Gender'].value_counts()
# Out:
# 0    423
# 1    409
# Name: Gender, dtype: int64

# %%
print("In this dataframe we have" ,ad_df_without_NAN['Gender'].value_counts()[1]," males and",ad_df_without_NAN['Gender'].value_counts()[0],"females")
# Out:
# In this dataframe we have 409  males and 423 females

# %%
ad_df_without_NAN['Clicked on Ad'].value_counts()
# Out:
# 0.0    419
# 1.0    413
# Name: Clicked on Ad, dtype: int64

# %%
print("In this dataframe " ,ad_df_without_NAN['Clicked on Ad'].value_counts()[1]," have clicked on Ad and ",ad_df_without_NAN['Clicked on Ad'].value_counts()[0],"have not")
# Out:
# In this dataframe  413  have clicked on Ad and  419 have not

# %% [markdown]
# part 5.

# %% [markdown]
# Im a 22-year-old female

# %%
ad_df_without_NAN_agelimited = ad_df_without_NAN[ad_df_without_NAN['Age'] > 22 ]
ad_df_without_NAN_agelimited_female = ad_df_without_NAN_agelimited[ad_df_without_NAN_agelimited['Gender']==0]
print(ad_df_without_NAN_agelimited_female)
# Out:
# Unnamed: 0  Daily Time Spent on Site        Age  Area Income  \
# 0             0                 68.950000  35.000000     61833.90
# 2             2                 69.470000  26.000000     59785.94
# 4             4                 68.370000  35.000000     73889.99
# 6             6                 88.910000  33.000000     53852.85
# 13           13                 79.520000  35.977914     51739.63
# ..          ...                       ...        ...          ...
# 982         982                 54.370000  38.000000     72196.29
# 985         985                 72.880000  44.000000     64011.26
# 989         989                 70.960000  31.000000     55187.85
# 994         994                 43.700000  28.000000     63126.96
# 999         999                 65.065488  26.000000     29875.80
#
#      Daily Internet Usage                        Ad Topic Line          City  \
# 0                  256.09   Cloned 5thgeneration orchestration   Wrightburgh
# ...

# %% [markdown]
# By limiting the dataset, we can see that there are 411 females over the age of 22

# %% [markdown]
# part 6.

# %% [markdown]
# This is the first method used, but this method does not correctly utilize vectorization

# %%
start=time.time()
clicked_mean_age = ad_df_without_NAN[ad_df_without_NAN['Clicked on Ad']==1].mean()['Age']
not_clicked_mean_age = ad_df_without_NAN[ad_df_without_NAN['Clicked on Ad']==0].mean()['Age']
end=time.time()
print('mean age of people who clicked', clicked_mean_age)
print('mean age of people who did not click', not_clicked_mean_age)
print('time without for :',end-start)
# Out:
# mean age of people who clicked 40.29491822516675
# mean age of people who did not click 31.722728670366198
# time without for : 0.051860809326171875

# %% [markdown]
# Below you can see the second method in which vectorization has been used correctly, hence, the needed time for the operation has become visibly less.

# %%
start=time.time()
clicked_mean_age = ((ad_df_without_NAN['Clicked on Ad']*ad_df_without_NAN['Age']).replace(0, np.NaN)).mean()
not_clicked_mean_age = ((ad_df_without_NAN['Clicked on Ad'].replace(1, np.NaN).replace(0, 1)*ad_df_without_NAN['Age']).replace(0, np.NaN)).mean()
end=time.time()
print('mean age of people who clicked', clicked_mean_age)
print('mean age of people who did not click', not_clicked_mean_age)
print('time without for :',end-start)
# Out:
# mean age of people who clicked 40.29491822516675
# mean age of people who did not click 31.722728670366198
# time without for : 0.00399017333984375

# %% [markdown]
# part 7.

# %%
start=time.time()
total_count = ad_df_without_NAN.count()[0]
clicked_count = 0
not_clicked_count = 0
clicked_tot_age = 0
not_clicked_tot_age = 0
for i in ad_df_without_NAN.index :
    if ad_df_without_NAN['Clicked on Ad'][i]==1.0 :
        clicked_tot_age += ad_df_without_NAN['Age'][i]
        clicked_count += 1
    else:
        not_clicked_tot_age += ad_df_without_NAN['Age'][i]
        not_clicked_count += 1
end=time.time()
print('mean age in clicked', clicked_tot_age/clicked_count)
print('mean age in not clicked', not_clicked_tot_age/not_clicked_count)
print('time using for',end-start)
# Out:
# mean age in clicked 40.29491822516675
# mean age in not clicked 31.722728670366198
# time using for 0.0548553466796875

# %% [markdown]
# Comaparing out puts, we can see that using vectorization in part 6. decreased the time enormously. Using 'for' for big datas that are used in AI is clearly not efficient.

# %% [markdown]
# part 8.

# %% [markdown]
# In this part, using hist function we can easily see the shape of distrubution in different columns.

# %%
ad_df_without_NAN.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002AAA3D05FC8>,
# ...
#       dtype=object)

# %%
ad_df_without_NAN.hist('Daily Time Spent on Site')
ad_df_without_NAN.hist('Age')
ad_df_without_NAN.hist('Area Income')
ad_df_without_NAN.hist('Daily Internet Usage')
ad_df_without_NAN.hist('Clicked on Ad')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002AAA558DDC8>]],
#       dtype=object)

# %% [markdown]
# part 9.

# %% [markdown]
# First we need to omit the categorical columns including gender.

# %%
only_number_ad_df = ad_df_without_NAN.drop(['Gender','Ad Topic Line','City','Country','Timestamp'], axis=1)

# %% [markdown]
# Here you can see the dataframe after categotrical columns have been dropped

# %%
only_number_ad_df
# Out:
#      Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 0             0                 68.950000  35.0     61833.90
# 1             1                 80.230000  31.0     68441.85
# 2             2                 69.470000  26.0     59785.94
# 3             3                 74.150000  29.0     54806.18
# 4             4                 68.370000  35.0     73889.99
# ..          ...                       ...   ...          ...
# 995         995                 72.970000  30.0     71384.57
# 996         996                 51.300000  45.0     67782.17
# 997         997                 51.630000  51.0     42415.72
# 998         998                 55.550000  19.0     41920.79
# 999         999                 65.065488  26.0     29875.80
#
#      Daily Internet Usage  Clicked on Ad
# 0              256.090000            0.0
# 1              180.252968            0.0
# 2              236.500000            0.0
# 3              245.890000            0.0
# ...

# %% [markdown]
# Below normalized datas have been calculated and shown.

# %%
normalized_ad_df = (only_number_ad_df-only_number_ad_df.mean())/only_number_ad_df.std()

# %%
normalized_ad_df
# Out:
#      Unnamed: 0  Daily Time Spent on Site       Age  Area Income  \
# 0     -1.712467              2.578170e-01 -0.111991     0.515328
# 1     -1.709021              1.006476e+00 -0.570070     1.006277
# 2     -1.705575              2.923296e-01 -1.142669     0.363171
# 3     -1.702129              6.029435e-01 -0.799109    -0.006809
# 4     -1.698683              2.193221e-01 -0.111991     1.411056
# ..          ...                       ...       ...          ...
# 995    1.716328              5.246264e-01 -0.684590     1.224911
# 996    1.719774             -9.136222e-01  1.033207     0.957265
# 997    1.723220             -8.917200e-01  1.720326    -0.927379
# 998    1.726666             -6.315476e-01 -1.944307    -0.964151
# 999    1.730112             -1.886363e-15 -1.142669    -1.859054
#
#      Daily Internet Usage  Clicked on Ad
# 0            1.794355e+00      -0.992217
# 1           -5.379814e-15      -0.992217
# 2            1.330843e+00      -0.992217
# ...

# %% [markdown]
# part 10.

# %% [markdown]
# First we separate the dataframe based on ads being clicked or not

# %%
clicked_normalized_ad_df = normalized_ad_df[normalized_ad_df['Clicked on Ad'] >1]
not_clicked_normalized_ad_df = normalized_ad_df[normalized_ad_df['Clicked on Ad'] <1]

# %% [markdown]
# We can see the mean and the std for the two seperated dataframes below

# %%
clicked_normalized_ad_df.mean()
# Out:
# Unnamed: 0                  0.026107
# Daily Time Spent on Site   -0.714149
# Age                         0.494382
# Area Income                -0.489377
# Daily Internet Usage       -0.759439
# Clicked on Ad               1.006632
# dtype: float64

# %%
clicked_normalized_ad_df.std()
# Out:
# Unnamed: 0                  1.030163e+00
# Daily Time Spent on Site    8.444196e-01
# Age                         1.014486e+00
# Area Income                 1.042708e+00
# Daily Internet Usage        7.206141e-01
# Clicked on Ad               6.002476e-15
# dtype: float64

# %%
not_clicked_normalized_ad_df.mean()
# Out:
# Unnamed: 0                 -0.025733
# Daily Time Spent on Site    0.703923
# Age                        -0.487303
# Area Income                 0.482369
# Daily Internet Usage        0.748564
# Clicked on Ad              -0.992217
# dtype: float64

# %%
not_clicked_normalized_ad_df.std()
# Out:
# Unnamed: 0                  9.698961e-01
# Daily Time Spent on Site    5.335057e-01
# Age                         7.029272e-01
# Area Income                 6.682390e-01
# Daily Internet Usage        5.870850e-01
# Clicked on Ad               9.337022e-15
# dtype: float64

# %% [markdown]
# Below we can see plot of the pdf function for the vatriable 'Daily Time Spent on Site' for when poeple have clicked and for when they have not, separately.

# %%
plt.plot(clicked_normalized_ad_df['Daily Time Spent on Site'] , norm.pdf(clicked_normalized_ad_df['Daily Time Spent on Site'],clicked_normalized_ad_df['Daily Time Spent on Site'].mean(),clicked_normalized_ad_df['Daily Time Spent on Site'].std()), 'r1', lw=2, alpha=0.1)

plt.plot(not_clicked_normalized_ad_df['Daily Time Spent on Site'], norm.pdf(not_clicked_normalized_ad_df['Daily Time Spent on Site'],not_clicked_normalized_ad_df['Daily Time Spent on Site'].mean(),not_clicked_normalized_ad_df['Daily Time Spent on Site'].std()),'r2', lw=2, alpha=0.5)


plt.show()

# %% [markdown]
# The plot that has a lighter color is for 'clicked' and the the darker plot is for 'not clicked'

# %%
plt.plot(clicked_normalized_ad_df['Age'], norm.pdf(clicked_normalized_ad_df['Age'],clicked_normalized_ad_df['Age'].mean(),clicked_normalized_ad_df['Age'].std()), 'r1', lw=2, alpha=0.1, label='norm PDF for Age')

plt.plot(not_clicked_normalized_ad_df['Age'], norm.pdf(not_clicked_normalized_ad_df['Age'],not_clicked_normalized_ad_df['Age'].mean(),not_clicked_normalized_ad_df['Age'].std()), 'r1', lw=2, alpha=0.5, label='norm PDF for Age')

plt.show()

# %% [markdown]
# The plot that has a lighter color is for 'clicked' and the the darker plot is for 'not clicked'

# %%
plt.plot(clicked_normalized_ad_df['Area Income'], norm.pdf(clicked_normalized_ad_df['Area Income'],clicked_normalized_ad_df['Area Income'].mean(),clicked_normalized_ad_df['Area Income'].std()), 'r1', lw=2, alpha=0.1)

plt.plot(not_clicked_normalized_ad_df['Area Income'], norm.pdf(not_clicked_normalized_ad_df['Area Income'],not_clicked_normalized_ad_df['Area Income'].mean(),not_clicked_normalized_ad_df['Area Income'].std()), 'r1', lw=2, alpha=0.5)

plt.show()

# %% [markdown]
# The plot that has a lighter color is for 'clicked' and the the darker plot is for 'not clicked'

# %%
plt.plot(clicked_normalized_ad_df['Daily Internet Usage'], norm.pdf(clicked_normalized_ad_df['Daily Internet Usage'],clicked_normalized_ad_df['Daily Internet Usage'].mean(),clicked_normalized_ad_df['Daily Internet Usage'].std()), 'r1', lw=2, alpha=0.1)

plt.plot(not_clicked_normalized_ad_df['Daily Internet Usage'], norm.pdf(not_clicked_normalized_ad_df['Daily Internet Usage'],not_clicked_normalized_ad_df['Daily Internet Usage'].mean(),not_clicked_normalized_ad_df['Daily Internet Usage'].std()),'r2', lw=2, alpha=0.5)

plt.show()

# %% [markdown]
# The plot that has a lighter color is for 'clicked' and the the darker plot is for 'not clicked'

# %% [markdown]
# By comparing all the plots, we can conclude that the variable 'Daily Internet Usage' is a suitable varible for the input of this model. This is because the two plots in this variable have the least shared area of the clicked and not clicked plots. Hence, knowing someone's age we can better determine whether that person is going to click on the ad or not.

# %% [markdown]
# part 11.

# %% [markdown]
# In this part we need to use the original data set that has empty cells.
# First, we need to fill the empty cells that belong to variables using the mean of their column, like we did in part 3.Then, we need to normalize the data like in part 9.  Then we can fill the empty cells in the aim column using the varible 'Daily Internet Usage' that we determined in part 10. Having the completed aim column, we can maked the asked csv file.

# %%
ad_df_nanfilled=ad_df.fillna(ad_df.mean())

# %%
ad_df_nanfilled['Clicked on Ad']=ad_df['Clicked on Ad']

# %% [markdown]
# Below we can see that the empty cells have been filled

# %%
ad_df_nanfilled.tail(50)
# Out:
#      Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 950         950                 63.990000  43.0     72802.42
# 951         951                 41.350000  27.0     39193.45
# 952         952                 62.790000  36.0     18368.57
# 953         953                 45.530000  29.0     56129.89
# 954         954                 51.650000  31.0     58996.56
# 955         955                 54.550000  44.0     41547.62
# 956         956                 35.660000  36.0     59240.24
# 957         957                 69.950000  28.0     56725.47
# 958         958                 79.830000  29.0     55764.43
# 959         959                 85.350000  37.0     64235.51
# 960         960                 64.794818  28.0     39939.39
# 961         961                 78.670000  26.0     63319.99
# 962         962                 70.090000  21.0     54725.87
# 963         963                 60.750000  42.0     69775.75
# ...

# %% [markdown]
# Then we should omit the categorial variables

# %%
only_number_ad_df = ad_df_nanfilled.drop(['Gender','Ad Topic Line','City','Country','Timestamp'], axis=1)

# %% [markdown]
# We can see the dataframe after categorical values have been dropped

# %%
only_number_ad_df.tail(50)
# Out:
#      Unnamed: 0  Daily Time Spent on Site   Age  Area Income  \
# 950         950                 63.990000  43.0     72802.42
# 951         951                 41.350000  27.0     39193.45
# 952         952                 62.790000  36.0     18368.57
# 953         953                 45.530000  29.0     56129.89
# 954         954                 51.650000  31.0     58996.56
# 955         955                 54.550000  44.0     41547.62
# 956         956                 35.660000  36.0     59240.24
# 957         957                 69.950000  28.0     56725.47
# 958         958                 79.830000  29.0     55764.43
# 959         959                 85.350000  37.0     64235.51
# 960         960                 64.794818  28.0     39939.39
# 961         961                 78.670000  26.0     63319.99
# 962         962                 70.090000  21.0     54725.87
# 963         963                 60.750000  42.0     69775.75
# ...

# %%
normalized_ad_df = (only_number_ad_df-only_number_ad_df.mean())/only_number_ad_df.std()
normalized_ad_df['Clicked on Ad']=ad_df['Clicked on Ad']

# %% [markdown]
# Below, we can see the dataframe after normalization

# %%
normalized_ad_df
# Out:
#      Unnamed: 0  Daily Time Spent on Site       Age  Area Income  \
# 0     -1.729454                  0.273474 -0.116122     0.509436
# 1     -1.725992                  1.015870 -0.576377     1.002029
# 2     -1.722530                  0.307698 -1.151696     0.356770
# 3     -1.719067                  0.615713 -0.806505    -0.014448
# 4     -1.715605                  0.235301 -0.116122     1.408163
# ..          ...                       ...       ...          ...
# 995    1.715605                  0.538051 -0.691441     1.221395
# 996    1.719067                 -0.888164  1.034517     0.952853
# 997    1.722530                 -0.866445  1.724900    -0.938101
# 998    1.725992                 -0.608450 -1.957144    -0.974996
# 999    1.729454                  0.000000 -1.151696    -1.872895
#
#      Daily Internet Usage  Clicked on Ad
# 0                1.817578            0.0
# 1                0.000000            0.0
# 2                1.351152            0.0
# ...

# %% [markdown]
# We should determine the intersection point between the 2 plots of the chosen variable. Seeing where a new person's 'Daily Internet Usage' lays(which side of the point), we can predict whether they will click on the ad or not. using this method we can fill the aim column.

# %% [markdown]
# Using the plot we can see that the intersection point is for x=0

# %%
separating_point=0

# %% [markdown]
# Now having this information we find the indexes and their aim column.

# %% [markdown]
# First we seperate rows that have NaN in their aim column.
# Then we determine those row's output based of the magnitude of the variable 'Daily Internet Usage'

# %%
just_nan_df=normalized_ad_df[pd.isnull(normalized_ad_df['Clicked on Ad'])]

# %%
 clicked_nan=just_nan_df['Daily Internet Usage'] < separating_point

# %%
clicked_nan
# Out:
# 10      True
# 14      True
# 15      True
# 20     False
# 24      True
#        ...
# 963    False
# 966     True
# 967    False
# 977     True
# 992     True
# Name: Daily Internet Usage, Length: 168, dtype: bool

# %%
clicked_nan = clicked_nan.astype(int)

# %%
clicked_nan
# Out:
# 10     1
# 14     1
# 15     1
# 20     0
# 24     1
#       ..
# 963    0
# 966    1
# 967    0
# 977    1
# 992    1
# Name: Daily Internet Usage, Length: 168, dtype: int32

# %%
clicked_nan.rename(columns={"Daily Internet Usage":"Clicked on Ad" })
# Out:
# 10     1
# 14     1
# 15     1
# 20     0
# 24     1
#       ..
# 963    0
# 966    1
# 967    0
# 977    1
# 992    1
# Length: 168, dtype: int32

# %% [markdown]
# Now we make the exel file including indexes and their [redicted outputs.

# %%
writer = pd.ExcelWriter('replaced_nan_with_index.xlsx')
clicked_nan.to_excel(writer)
writer.save()
print('Information is written successfully to Excel File.')
# Out:
# Information is written successfully to Excel File.
